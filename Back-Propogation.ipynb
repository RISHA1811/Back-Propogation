# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]], columns=['cgpa','profle_score','LPA']) ## Making our own dataset

# %%
df.head()
# Out:
#    cgpa  profle_score  LPA
# 0     8             8    4
# 1     7             9    5
# 2     6            10    6
# 3     5            12    7

# %%
## Ye kyu likha ha maine , mere parameters jaise Weights and Bias Ko initialized karne ke liye 
def initialize_parameters(layer_dims):  
    np.random.seed(3)
    parameters= {}
    L= len(layer_dims)

    for l in range(1,L):
        parameters['W' + str(l)] = np.ones((layer_dims[l-1], layer_dims[l]))*0.1
        parameters['b' + str(l)] = np.zeros((layer_dims[l], 1))

    return parameters

# %%
initialize_parameters([2,2,1])
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
def linear_forward(A_prev, W,b):
    z = np.dot(W.T, A_prev) + b
    return z

# %%
## Main function which will do the forward propagation
def L_layer_forward(X,parameters):
    A=X
    L=len(parameters) // 2 
    for l in range(1, L+1):
        A_prev = A
        w1 = parameters['W' + str(l)]
        b1 = parameters['b' + str(l)]
        print("A" + str(l-1)+": ", A_prev)
        print("W"+str(l)+": ", w1)
        print("b"+str(l)+": ",b1)
        print("--"*20)

        A = linear_forward(A_prev, w1, b1)
        print("A"+str(l)+": ",A)
        print("=="*20)
    return A,A_prev

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          4 non-null      int64
#  1   profle_score  4 non-null      int64
#  2   LPA           4 non-null      int64
# dtypes: int64(3)
# memory usage: 228.0 bytes

# %%
x=df[['cgpa','profle_score']].values[0].reshape(2,1)
y=df[['LPA']].values[0][0]
parameters = initialize_parameters([2,2,1])
y_hat,A1=L_layer_forward(x,parameters)
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# ...
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# ...

# %%
## Loss Calculation
(y-0.32)**2
y_hat
update_parameters(parameters,y,y_hat,A1,x)
import warnings
warnings.filterwarnings('ignore')

# %%
x=df[['cgpa','profle_score']].values[1].reshape(2,1)
y=df[['LPA']].values[1][0]
y_hat,A1=L_layer_forward(x,parameters)
# Out:
# A0:  [[7]
#  [9]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# ...
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# ...

# %%
x=df[['cgpa','profle_score']].values[2].reshape(2,1)
y=df[['LPA']].values[2][0]
y_hat,A1=L_layer_forward(x,parameters)
# Out:
# A0:  [[ 6]
#  [10]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# ...
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# ...

# %%
x=df[['cgpa','profle_score']].values[3].reshape(2,1)
y=df[['LPA']].values[3][0]
y_hat,A1=L_layer_forward(x,parameters)
# Out:
# A0:  [[ 5]
#  [12]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.7]
#  [1.7]]
# ...
# A1:  [[1.7]
#  [1.7]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.34]]
# ...

# %%
parameters
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
def  update_parameters(parameters, y, y_hat,A1,X): ## Here we use the formula for weight(new)= weight(old)-n*differentiation wrt bias
    parameters['W2'][0][0] = parameters['W2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
    parameters['W2'][1][0] = parameters['W2'][1][0] + (0.001*2*(y-y_hat)*A1[0][0])
    parameters['b2'][0][0] = parameters['W2'][1][0] + (0.001*2*(y-y_hat))
    
    parameters['W1'][0][0] = parameters['W1'][0][0] + (0.001*2*(y-y_hat)*parameters['W2'][0][0]*x[0][0])
    parameters['W1'][0][1] = parameters['W1'][0][1] + (0.001*2*(y-y_hat)*parameters['W2'][0][0]*x[1][0])
    parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['W2'][0][0])
    
    parameters['W1'][1][0] = parameters['W1'][1][0] + (0.001*2*(y-y_hat)*parameters['W2'][1][0]*x[0][0])
    parameters['W1'][1][1] = parameters['W1'][1][1] + (0.001*2*(y-y_hat)*parameters['W2'][1][0]*x[1][0])
    parameters['W2'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['W2'][1][0])

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
## Epochs Implimentation
parameters = initialize_parameters([2,2,1])
epochs = 5
for i in range(epochs):
    Loss = []
    for j in range(df.shape[0]):
        x=df[['cgpa','profle_score']].values[j].reshape(2,1)
        y=df[['LPA']].values[j][0]
        y_hat,A1=L_layer_forward(x,parameters)

        update_parameters(parameters,y,y_hat,A1,x)
        Loss.append((y-y_hat)**2)
    print(("Loss Value will be",(y-y_hat)**2))
    print('Epoch - ' , i+1 , 'Loss - ' ,np.array(Loss).mean())
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# ...
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# ...
# A0:  [[7]
#  [9]]
# W1:  [[0.10658137 0.10658137]
#  [0.10658137 0.10658137]]
# b1:  [[0.00082267]
#  [0.        ]]
# ----------------------------------------
# A1:  [[1.70612461]
#  [1.70530193]]
# ...
# A1:  [[1.70612461]
#  [1.70530193]]
# W2:  [[0.111776  ]
#  [0.00082267]]
# b2:  [[0.119136]]
# ----------------------------------------
# A2:  [[0.31124269]]
# ...
# A0:  [[ 6]
#  [10]]
# W1:  [[0.11496887 0.1173653 ]
#  [0.1076856  0.1080011 ]]
# b1:  [[0.00202089]
#  [0.        ]]
# ----------------------------------------
# A1:  [[1.76869012]
#  [1.78420275]]
# ...
# A1:  [[1.76869012]
#  [1.78420275]]
# W2:  [[0.12777521]
#  [0.00015775]]
# b2:  [[0.02619939]]
# ----------------------------------------
# A2:  [[0.2524756]]
# ...
# A0:  [[ 5]
# ...
